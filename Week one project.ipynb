# %% [markdown]
# # Week One code

# %%
import pandas as pd

# %%
ha_costs_df = pd.read_csv ('data/mmd_heart_attack_data.csv')

# %%
ha_costs_df.head(5)
# Out:
#    year geography             measure         adjustment      analysis  \
# 0  2017    County  Average total cost  Unsmoothed actual  Base measure
# 1  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3  2017    County  Average total cost  Unsmoothed actual  Base measure
# 4  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                        domain                    condition primary_sex  \
# 0  Primary chronic conditions  Acute myocardial infarction         All
# 1  Primary chronic conditions  Acute myocardial infarction         All
# 2  Primary chronic conditions  Acute myocardial infarction         All
# 3  Primary chronic conditions  Acute myocardial infarction         All
# 4  Primary chronic conditions  Acute myocardial infarction         All
#
#   primary_age     primary_dual  fips          county    state  urban  \
# ...

# %%
ha_costs_df.tail(5)
# Out:
#       year geography             measure         adjustment      analysis  \
# 2651  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2652  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2653  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2654  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2655  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                    condition primary_sex  \
# 2651  Primary chronic conditions  Acute myocardial infarction         All
# 2652  Primary chronic conditions  Acute myocardial infarction         All
# 2653  Primary chronic conditions  Acute myocardial infarction         All
# 2654  Primary chronic conditions  Acute myocardial infarction         All
# 2655  Primary chronic conditions  Acute myocardial infarction         All
#
#      primary_age     primary_dual   fips                   county  \
# ...

# %%
ha_costs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2656 entries, 0 to 2655
# Data columns (total 17 columns):
# year                   2656 non-null int64
# geography              2656 non-null object
# measure                2656 non-null object
# adjustment             2656 non-null object
# analysis               2656 non-null object
# domain                 2656 non-null object
# condition              2656 non-null object
# primary_sex            2656 non-null object
# primary_age            2656 non-null object
# primary_dual           2656 non-null object
# fips                   2656 non-null int64
# county                 2656 non-null object
# state                  2656 non-null object
# urban                  2656 non-null object
# primary_race           2656 non-null object
# primary_denominator    2656 non-null object
# analysis_value         2656 non-null int64
# dtypes: int64(3), object(14)
# memory usage: 352.8+ KB

# %%
TN_ha = ha_costs_df[ha_costs_df.state == 'TENNESSEE']

# %%
TN_ha.shape
# Out:
# (91, 17)

# %%
# 91 county

# %%
TN_ha ['county'].value_counts()
# Out:
# Knox County          1
# Jefferson County     1
# Dyer County          1
# Houston County       1
# Greene County        1
# Hawkins County       1
# Carter County        1
# Crockett County      1
# Cocke County         1
# Blount County        1
# Lake County          1
# Trousdale County     1
# Macon County         1
# Sevier County        1
# Anderson County      1
# Grundy County        1
# Rhea County          1
# Grainger County      1
# Lincoln County       1
# Rutherford County    1
# Morgan County        1
# Hardeman County      1
# Davidson County      1
# Decatur County       1
# Montgomery County    1
# Claiborne County     1
# Perry County         1
# White County         1
# Meigs County         1
# Overton County       1
#                     ..
# Tipton County        1
# Madison County       1
# Wayne County         1
# Chester County       1
# Henry County         1
# Lauderdale County    1
# Lewis County         1
# Marshall County      1
# McNairy County       1
# ...

# %%
TN_ha ['urban'].value_counts()
# Out:
# Rural    53
# Urban    38
# Name: urban, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
TN_ha['analysis_value'].describe()
# Out:
# count       91.000000
# mean     45762.989011
# std       6574.670462
# min      30831.000000
# 25%      41105.500000
# 50%      45384.000000
# 75%      49698.500000
# max      62641.000000
# Name: analysis_value, dtype: float64

# %%
plt.scatter(TN_ha['analysis_value'], TN_ha['urban'])

# %%
#Yes rural cost seems higher

# %%
import numpy as np

# %%
#don't know how to do average on graph

# %%
cancer_costs_df = pd.read_csv ('data/mmd_cancer_data.csv')

# %%
cancer_costs_df.head()
# Out:
#    year geography             measure         adjustment      analysis  \
# 0  2017    County  Average total cost  Unsmoothed actual  Base measure
# 1  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3  2017    County  Average total cost  Unsmoothed actual  Base measure
# 4  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                        domain                                   condition  \
# 0  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 1  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 2  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 4  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
#
#   primary_sex primary_age     primary_dual  fips          county    state  \
# ...

# %%
cancer_costs_df.tail()
# Out:
#       year geography             measure         adjustment      analysis  \
# 3160  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3161  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3162  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3163  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3164  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                                   condition  \
# 3160  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3161  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3162  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3163  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3164  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
#
# ...

# %%
cancer_costs_df.shape
# Out:
# (3165, 17)

# %%
TN_cancer = cancer_costs_df[cancer_costs_df.state == 'TENNESSEE']

# %%
TN_cancer.shape
# Out:
# (95, 17)

# %%
TN_cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95 entries, 2396 to 2490
# Data columns (total 17 columns):
# year                   95 non-null int64
# geography              95 non-null object
# measure                95 non-null object
# adjustment             95 non-null object
# analysis               95 non-null object
# domain                 95 non-null object
# condition              95 non-null object
# primary_sex            95 non-null object
# primary_age            95 non-null object
# primary_dual           95 non-null object
# fips                   95 non-null int64
# county                 95 non-null object
# state                  95 non-null object
# urban                  95 non-null object
# primary_race           95 non-null object
# primary_denominator    95 non-null object
# analysis_value         95 non-null int64
# dtypes: int64(3), object(14)
# memory usage: 13.4+ KB

# %%
#95 county

# %%
TN_cancer ['county'].value_counts()
# Out:
# Knox County          1
# Trousdale County     1
# Dyer County          1
# Houston County       1
# Greene County        1
# Hawkins County       1
# Carter County        1
# Crockett County      1
# Cocke County         1
# Blount County        1
# Lake County          1
# Macon County         1
# Jefferson County     1
# Sevier County        1
# Anderson County      1
# Grundy County        1
# Rhea County          1
# Grainger County      1
# Lincoln County       1
# Rutherford County    1
# Pickett County       1
# Morgan County        1
# Hardeman County      1
# Davidson County      1
# Decatur County       1
# Carroll County       1
# Claiborne County     1
# Perry County         1
# White County         1
# Meigs County         1
#                     ..
# Madison County       1
# Wayne County         1
# Chester County       1
# Henry County         1
# Lauderdale County    1
# Lewis County         1
# Marshall County      1
# Hancock County       1
# Loudon County        1
# ...

# %%
TN_county = pd.merge(TN_cancer, TN_ha.county, on = ['county'], how='outer')

# %%
TN_county.tail()
# Out:
#     year geography             measure         adjustment      analysis  \
# 90  2017    County  Average total cost  Unsmoothed actual  Base measure
# 91  2017    County  Average total cost  Unsmoothed actual  Base measure
# 92  2017    County  Average total cost  Unsmoothed actual  Base measure
# 93  2017    County  Average total cost  Unsmoothed actual  Base measure
# 94  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                         domain                                   condition  \
# 90  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 91  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 92  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 93  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 94  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
#
#    primary_sex primary_age     primary_dual   fips             county  \
# ...

# %%
TN_cancer_county = TN_cancer.county

# %%
TN_ha_county = TN_ha.county

# %%
TN_county_dif = pd.concat([TN_cancer_county, TN_ha_county])
TN_county_dif = TN_county_dif.reset_index(drop=True)

# %%
TN_county_dif_gpby = TN_county_dif.groupby(list(TN_county_dif))

# %%
idx = [x[0] for x in TN_county_dif_gpby.groups.values() if len(x) == 1]

# %%
TN_county_dif.reindex(idx)
# Out:
# 33      Hancock County
# 63        Moore County
# 68      Pickett County
# 87    Van Buren County
# Name: county, dtype: object

# %% [markdown]
# ### the extra counties in cancer are Hancock, Moore, Pickett and Van Buren?

# %%
plt.scatter(TN_cancer['analysis_value'], TN_cancer['urban'])

# %%
income_df = pd.read_csv ('data/irs_county_2016.csv')

# %%
income_df.head()
# Out:
#    STATEFIPS STATE  COUNTYFIPS COUNTYNAME  agi_stub      N1   mars1   MARS2  \
# 0          1    AL           0    Alabama         1   26450   14680    9740
# 1          1    AL           0    Alabama         2  285760  217880   25170
# 2          1    AL           0    Alabama         3  529780  259680   80320
# 3          1    AL           0    Alabama         4  495750  211100  141800
# 4          1    AL           0    Alabama         5  263130   82330  137610
#
#     MARS4    PREP  ...  N10300   A10300  N85530  A85530  N85300  A85300  \
# 0     680   17780  ...    4300     9256      70      57       0       0
# 1   39740  143390  ...   70050    40569       0       0       0       0
# 2  181410  297440  ...  297770   290358       0       0       0       0
# 3  127420  272030  ...  397940   983800      40      22       0       0
# 4   35760  154540  ...  252940  1346083      20      27       0       0
#
#    N11901  A11901  N11902   A11902
# 0    2590    3685   11510    35079
# ...

# %%
TN_income = income_df[income_df.STATE == 'TN']

# %%
TN_income.head()
# Out:
#        STATEFIPS STATE  COUNTYFIPS COUNTYNAME  agi_stub      N1   mars1  \
# 19752         47    TN           0  Tennessee         1   39580   22400
# 19753         47    TN           0  Tennessee         2  439770  345410
# 19754         47    TN           0  Tennessee         3  717430  398720
# 19755         47    TN           0  Tennessee         4  759340  355970
# 19756         47    TN           0  Tennessee         5  396810  128390
#
#         MARS2   MARS4    PREP  ...  N10300   A10300  N85530  A85530  N85300  \
# 19752   14440     980   25390  ...    6760    17669     200     287       0
# 19753   39920   49300  188490  ...  109250    62045       0       0       0
# 19754  115040  189290  341750  ...  449870   461060       0       0       0
# 19755  217710  159890  347430  ...  629080  1669328     110     100       0
# 19756  215890   42240  198820  ...  382580  2135577      30      29       0
#
#        A85300  N11901  A11901  N11902   A11902
# ...

# %%
TN_income.tail()
# Out:
#        STATEFIPS STATE  COUNTYFIPS     COUNTYNAME  agi_stub     N1  mars1  \
# 20515         47    TN         189  Wilson County         4  14400   7130
# 20516         47    TN         189  Wilson County         5   9330   2890
# 20517         47    TN         189  Wilson County         6   7160   1060
# 20518         47    TN         189  Wilson County         7  10350    780
# 20519         47    TN         189  Wilson County         8   2370    180
#
#        MARS2  MARS4  PREP  ...  N10300  A10300  N85530  A85530  N85300  \
# 20515   4050   2610  6520  ...   12340   34654       0       0       0
# 20516   5160    960  4600  ...    9010   50591       0       0       0
# 20517   5630    380  3560  ...    7110   61964       0       0       0
# 20518   9260    240  5330  ...   10330  190229      60      13       0
# 20519   2130     50  1700  ...    2370  230759    1160    1817    1080
#
#        A85300  N11901  A11901  N11902  A11902
# 20515       0    2090    4150   12140   31712
# ...

# %%
TN_income.shape
# Out:
# (768, 148)

# %%
TN_income_sim = TN_income[['STATE', 'COUNTYNAME', 'agi_stub', 'N1', 'mars1', 'MARS2', 'MARS4', 'N2', 'NUMDEP', 
                           'ELDERLY', 'A00100', 'N02650', 'A02650', 'N02300', 'A02300']]

# %%
TN_income_sim = TN_income_sim.rename(columns = {'STATE': 'state', 'COUNTYNAME': 'county', 'agi_stub': 'income_bucket',
                                                'N1': 'return_count', 'mars1': 'single_returns',
                                                'MARS2': 'joint_returns', 'MARS4':'head_of_house_returns',
                                               'N2':'exemptions', 'NUMDEP':'dependents', 
                                                'ELDERLY': 'elderly','A00100': 'agi', 
                                                'N02650': 'returns_with_total_inc', 'A02650': 'total_inc_amt', 
                                                'N02300': 'returns_with_unemployment', 'A02300': 'unemployment_comp'})

# %%
TN_income_sim.head()
# Out:
#       state     county  income_bucket  return_count  single_returns  \
# 19752    TN  Tennessee              1         39580           22400
# 19753    TN  Tennessee              2        439770          345410
# 19754    TN  Tennessee              3        717430          398720
# 19755    TN  Tennessee              4        759340          355970
# 19756    TN  Tennessee              5        396810          128390
#
#        joint_returns  head_of_house_returns  exemptions  dependents  elderly  \
# 19752          14440                    980       60360        8230    19090
# 19753          39920                  49300      443540      108380    74190
# 19754         115040                 189290     1269420      472350   141070
# 19755         217710                 159890     1486710      512170   154020
# 19756         215890                  42240      881020      268500   106740
#
#             agi  returns_with_total_inc  total_inc_amt  \
# ...

# %%
pd.concat?
